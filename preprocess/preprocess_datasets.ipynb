# %%
import os
import numpy as np
import pandas as pd
import librosa
import dvc

# %%
COLUMNS = ['audio_path', 'audio_len', 'language', 'language_family', 'gender', 'emotion']
DATA_PATH = 'D:/licencjat/data/databases'
DF_PATH = 'D:/licencjat/data/dataframes'

# %% [markdown]
# RAVDNESS

# %% [markdown]
# Filename identifiers:
#
# Modality (01 = full-AV, 02 = video-only, 03 = audio-only).
#
# Vocal channel (01 = speech, 02 = song).
#
# Emotion (01 = neutral, 02 = calm, 03 = happy, 04 = sad, 05 = angry, 06 = fearful, 07 = disgust, 08 = surprised).
#
# Emotional intensity (01 = normal, 02 = strong). NOTE: There is no strong intensity for the 'neutral' emotion.
#
# Statement (01 = "Kids are talking by the door", 02 = "Dogs are sitting by the door").
#
# Repetition (01 = 1st repetition, 02 = 2nd repetition).
#
# Actor (01 to 24. Odd numbered actors are male, even numbered actors are female).
#
# Filename example: 03-01-06-01-02-01-12.wav
#
# Audio-only (03)
# Speech (01)
# Fearful (06)
# Normal intensity (01)
# Statement "dogs" (02)
# 1st Repetition (01)
# 12th Actor (12)
# Female, as the actor ID number is even.

# %%
ravdness_path = f'{DATA_PATH}/ravdness'
ravdness_df = pd.DataFrame(columns=COLUMNS)
ravdness_language = 'enUS'
ravdness_language_family = 'Indo-European'

emotion_map_ravdness = {'01' : 'neutral', 
                        '02' : 'neutral', 
                        '03' : 'happy', 
                        '04' : 'sad', 
                        '05' : 'angry',
                        '06' : 'fearful',
                        '07' : 'disgusted',
                        '08' : 'surprised'}

# %%
for actor in os.listdir(ravdness_path):
    for audio_filename in os.listdir(f'{ravdness_path}/{actor}'):
        audio_path = f'{ravdness_path}/{actor}/{audio_filename}'
        
        audio_filename_splitted = audio_filename.split('-')
        emotion = emotion_map_ravdness[audio_filename_splitted[2]]
        audio_file, sr = librosa.load(audio_path)
        audio_len = str(f'{len(audio_file) / sr}')

        if int(audio_filename_splitted[-1][:-4]) % 2 == 0:
            gender = 'female'
        else:
            gender = 'male'
        
        df_row = pd.Series({'audio_path' : audio_path, 'audio_len' : audio_len, 'language' : ravdness_language, 'language_family' : ravdness_language_family, 'gender': gender, 'emotion' : emotion})
        ravdness_df = ravdness_df.append(df_row, ignore_index=True)

# %%
ravdness_df.to_csv(f'{DF_PATH}/ravdness_df.csv')
ravdness_df.head()
# Out:
#                                           audio_path           audio_len  \
# 0  D:/licencjat/data/databases/ravdness/Actor_01/...  3.3033106575963718
# 1  D:/licencjat/data/databases/ravdness/Actor_01/...   3.336689342403628
# 2  D:/licencjat/data/databases/ravdness/Actor_01/...  3.2699319727891156
# 3  D:/licencjat/data/databases/ravdness/Actor_01/...  3.1698412698412697
# 4  D:/licencjat/data/databases/ravdness/Actor_01/...    3.53687074829932
#
#   language language_family gender  emotion
# 0     enUS   Indo-European   male  neutral
# 1     enUS   Indo-European   male  neutral
# 2     enUS   Indo-European   male  neutral
# 3     enUS   Indo-European   male  neutral
# 4     enUS   Indo-European   male  neutral

# %% [markdown]
# Berlin EmoDB

# %%
emodb_path = f'{DATA_PATH}/Berlin_EMODB/wav'
emodb_df = pd.DataFrame(columns=COLUMNS)
emodb_language = 'deDE'
emodb_language_family = 'Indo-European'

speaker_gender_map_emodb = {'03' : 'male',
                            '08' : 'female',
                            '09' : 'female',
                            '10' : 'male',
                            '11' : 'male',
                            '12' : 'male',
                            '13' : 'female',
                            '14' : 'female',
                            '15' : 'male',
                            '16' : 'female'}

emotion_map_emodb = {'W' : 'angry', 
                     'L' : 'bored', 
                     'E' : 'disgusted',
                     'A' : 'fearful', 
                     'F' : 'happy',
                     'T' : 'sad',
                     'N' : 'neutral'}

# %%
for audio_filename in os.listdir(emodb_path):
    audio_path = f'{emodb_path}/{audio_filename}'
    speaker = audio_filename[:2]

    audio_file, sr = librosa.load(audio_path)
    audio_len = str(f'{len(audio_file) / sr}')
    
    gender = speaker_gender_map_emodb[speaker]
    emotion = emotion_map_emodb[audio_filename[5]]
    
    df_row = pd.Series({'audio_path' : audio_path, 'audio_len' : audio_len, 'language' : emodb_language, 'language_family' : emodb_language_family, 'gender': gender, 'emotion' : emotion})
    emodb_df = emodb_df.append(df_row, ignore_index=True)

# %%
emodb_df.to_csv(f'{DF_PATH}/berlin_emodb_df.csv')
emodb_df.head()
# Out:
#                                           audio_path           audio_len  \
# 0  D:/licencjat/data/databases/Berlin_EMODB/wav/0...  1.8982766439909298
# 1  D:/licencjat/data/databases/Berlin_EMODB/wav/0...  1.6112925170068026
# 2  D:/licencjat/data/databases/Berlin_EMODB/wav/0...  1.8778231292517007
# 3  D:/licencjat/data/databases/Berlin_EMODB/wav/0...  2.0062585034013605
# 4  D:/licencjat/data/databases/Berlin_EMODB/wav/0...  1.4398185941043085
#
#   language language_family gender  emotion
# 0     deDE   Indo-European   male    happy
# 1     deDE   Indo-European   male  neutral
# 2     deDE   Indo-European   male    angry
# 3     deDE   Indo-European   male    happy
# 4     deDE   Indo-European   male  neutral

# %% [markdown]
# SAVEE

# %%
savee_path = f'{DATA_PATH}/savee/ALL'
savee_df = pd.DataFrame(columns=COLUMNS)
savee_language = 'enGB'
savee_language_family = 'Indo-European'
gender = 'male'

emotion_map_savee = {'n' : 'neutral', 
                     'a' : 'angry', 
                     'd' : 'disgusted',
                     'f' : 'fearful', 
                     'h' : 'happy',
                     'sa' : 'sad',
                     'su' : 'surprised'}

# %%
for audio_filename in os.listdir(savee_path):
    audio_path = f'{savee_path}/{audio_filename}'
    audio_filename_splitted = audio_filename.split('_')
    emotion = emotion_map_savee[audio_filename_splitted[1][:-6]]
    audio_file, sr = librosa.load(audio_path)
    audio_len = str(f'{len(audio_file) / sr}')
    
    df_row = pd.Series({'audio_path' : audio_path, 'audio_len' : audio_len, 'language' : savee_language, 'language_family' : savee_language_family, 'gender': gender, 'emotion' : emotion})
    savee_df = savee_df.append(df_row, ignore_index=True)

# %%
savee_df.to_csv(f'{DF_PATH}/savee_df.csv')
savee_df.head()
# Out:
#                                          audio_path           audio_len  \
# 0  D:/licencjat/data/databases/savee/ALL/DC_a01.wav  3.6478004535147392
# 1  D:/licencjat/data/databases/savee/ALL/DC_a02.wav   3.438140589569161
# 2  D:/licencjat/data/databases/savee/ALL/DC_a03.wav  2.0755102040816324
# 3  D:/licencjat/data/databases/savee/ALL/DC_a04.wav  2.7253514739229026
# 4  D:/licencjat/data/databases/savee/ALL/DC_a05.wav  2.9979138321995467
#
#   language language_family gender emotion
# 0     enGB   Indo-European   male   angry
# 1     enGB   Indo-European   male   angry
# 2     enGB   Indo-European   male   angry
# 3     enGB   Indo-European   male   angry
# 4     enGB   Indo-European   male   angry

# %% [markdown]
# TESS

# %%
tess_path = f'{DATA_PATH}/TESS'
tess_df = pd.DataFrame(columns=COLUMNS)
tess_language = 'enCA'
tess_language_family = 'Indo-European'

# %%
for actor in os.listdir(tess_path):
    for audio_filename in os.listdir(f'{tess_path}/{actor}'):
        audio_path = f'{tess_path}/{actor}/{audio_filename}'
        audio_filename_splitted = audio_filename.split('_') 

        emotion = audio_filename_splitted[2][:-4]

        if emotion == 'fear':
            emotion = 'fearful'
        if emotion == 'ps':
            emotion = 'surprised'
        if emotion == 'disgust':
            emotion = 'disgusted'
        
        audio_file, sr = librosa.load(audio_path)
        audio_len = str(f'{len(audio_file) / sr}')

        df_row = pd.Series({'audio_path' : audio_path, 'audio_len' : audio_len, 'language' : tess_language, 'language_family' : tess_language_family, 'gender': gender, 'emotion' : emotion})
        tess_df = tess_df.append(df_row, ignore_index=True)

# %%
tess_df.to_csv(f'{DF_PATH}/tess_df.csv')
tess_df.head()
# Out:
#                                           audio_path           audio_len  \
# 0  D:/licencjat/data/databases/TESS/OAF_angry/OAF...   1.539047619047619
# 1  D:/licencjat/data/databases/TESS/OAF_angry/OAF...  1.6166439909297052
# 2  D:/licencjat/data/databases/TESS/OAF_angry/OAF...  1.5420408163265307
# 3  D:/licencjat/data/databases/TESS/OAF_angry/OAF...   1.606893424036281
# 4  D:/licencjat/data/databases/TESS/OAF_angry/OAF...  1.3951927437641722
#
#   language language_family  gender emotion
# 0     enCA   Indo-European  female   angry
# 1     enCA   Indo-European  female   angry
# 2     enCA   Indo-European  female   angry
# 3     enCA   Indo-European  female   angry
# 4     enCA   Indo-European  female   angry

# %% [markdown]
# EMOVO

# %%
emovo_path = f'{DATA_PATH}/emovo'
emovo_df = pd.DataFrame(columns=COLUMNS)
emovo_language = 'itIT'
emovo_language_family = 'Indo-European'

emotion_map_emovo = {'neu' : 'neutral', 
                     'rab' : 'angry', 
                     'dis' : 'disgusted',
                     'pau' : 'fearful', 
                     'gio' : 'happy',
                     'tri' : 'sad',
                     'sor' : 'surprised'}

gender_map_emovo = {'f' : 'female',
                    'm' : 'male'}

# %%
for actor in os.listdir(emovo_path):
    for audio_filename in os.listdir(f'{emovo_path}/{actor}'):
        audio_path = f'{emovo_path}/{actor}/{audio_filename}'
        audio_filename_splitted = audio_filename.split('-')

        gender = gender_map_emovo[audio_filename_splitted[1][0]]
        emotion = emotion_map_emovo[audio_filename_splitted[0]]

        audio_file, sr = librosa.load(audio_path)
        audio_len = str(f'{len(audio_file) / sr}')

        df_row = pd.Series({'audio_path' : audio_path, 'audio_len' : audio_len, 'language' : emovo_language, 'language_family' : emovo_language_family, 'gender': gender, 'emotion' : emotion})
        emovo_df = emovo_df.append(df_row, ignore_index=True)

# %%
emovo_df.to_csv(f'{DF_PATH}/emovo_df.csv')
emovo_df.head()

# %% [markdown]
# AESDD

# %%
aesdd_path = f'{DATA_PATH}/AESDD'
aesdd_df = pd.DataFrame(columns=COLUMNS)
aesdd_language = 'grGR'
aesdd_language_family = 'Indo-European'

emotion_map_aesdd = {'a' : 'angry', 
                     'd' : 'disgusted', 
                     'f' : 'fearful',
                     'h' : 'happy', 
                     's' : 'sad'}

gender_map_aesdd = {'1' : 'female',
                    '2' : 'female',
                    '3' : 'male',
                    '4' : 'male',
                    '5' : 'female',
                    '6' : 'male'}

# %%
for subdir in os.listdir(aesdd_path):
    for audio_filename in os.listdir(f'{aesdd_path}/{subdir}'):
        audio_path = f'{aesdd_path}/{subdir}/{audio_filename}'
        audio_filename_splitted = audio_filename.split()

        gender = gender_map_aesdd[audio_filename_splitted[1].strip('(0)b.wav')]
        emotion = emotion_map_aesdd[audio_filename_splitted[0][0]]

        audio_file, sr = librosa.load(audio_path)
        audio_len = str(f'{len(audio_file) / sr}')

        df_row = pd.Series({'audio_path' : audio_path, 'audio_len' : audio_len, 'language' : aesdd_language, 'language_family' : aesdd_language_family, 'gender': gender, 'emotion' : emotion})
        aesdd_df = aesdd_df.append(df_row, ignore_index=True)

# %%
aesdd_df.to_csv(f'{DF_PATH}/aesdd_df.csv')
aesdd_df.head()
# Out:
#                                           audio_path           audio_len  \
# 0  D:/licencjat/data/databases/AESDD/anger/a01 (1...   4.149115646258504
# 1  D:/licencjat/data/databases/AESDD/anger/a01 (1...   4.149115646258504
# 2  D:/licencjat/data/databases/AESDD/anger/a01 (1...   4.149115646258504
# 3  D:/licencjat/data/databases/AESDD/anger/a01 (2...  3.4778684807256237
# 4  D:/licencjat/data/databases/AESDD/anger/a01 (3...                 4.0
#
#   language language_family  gender emotion
# 0     grGR   Indo-European  female   angry
# 1     grGR   Indo-European  female   angry
# 2     grGR   Indo-European  female   angry
# 3     grGR   Indo-European  female   angry
# 4     grGR   Indo-European    male   angry

# %% [markdown]
# MESD

# %%
mesd_path = f'{DATA_PATH}/MESD'
mesd_df = pd.DataFrame(columns=COLUMNS)
mesd_language = 'esMX'
mesd_language_family = 'Indo-European'

emotion_map_mesd = {'Anger' : 'angry', 
                    'Disgust' : 'disgusted', 
                    'Fear' : 'fearful',
                    'Happiness' : 'happy', 
                    'Sadness' : 'sad',
                    'Neutral' : 'neutral'}

gender_map_mesd = {'M' : 'male',
                    'F' : 'female'}

# %%
for audio_filename in os.listdir(mesd_path):
    audio_path = f'{mesd_path}/{audio_filename}'

    audio_filename_splitted = audio_filename.split('_')
    gender = audio_filename_splitted[1]

    if gender == 'M' or gender == 'F':
        gender = gender_map_mesd[gender]
        emotion = emotion_map_mesd[audio_filename_splitted[0]]

        audio_file, sr = librosa.load(audio_path)
        audio_len = str(f'{len(audio_file) / sr}')
        
        df_row = pd.Series({'audio_path' : audio_path, 'audio_len' : audio_len, 'language' : mesd_language, 'language_family' : mesd_language_family, 'gender': gender, 'emotion' : emotion})
        mesd_df = mesd_df.append(df_row, ignore_index=True)

# %%
mesd_df.to_csv(f'{DF_PATH}/mesd_df.csv')
mesd_df.head()
# Out:
#                                           audio_path           audio_len  \
# 0  D:/licencjat/data/databases/MESD/Anger_F_A_aba...  0.6680725623582766
# 1  D:/licencjat/data/databases/MESD/Anger_F_A_adi...  0.4980952380952381
# 2  D:/licencjat/data/databases/MESD/Anger_F_A_ant...  0.8148299319727891
# 3  D:/licencjat/data/databases/MESD/Anger_F_A_arr...   0.766984126984127
# 4  D:/licencjat/data/databases/MESD/Anger_F_A_aye...  0.7198639455782313
#
#   language language_family  gender emotion
# 0     esMX   Indo-European  female   angry
# 1     esMX   Indo-European  female   angry
# 2     esMX   Indo-European  female   angry
# 3     esMX   Indo-European  female   angry
# 4     esMX   Indo-European  female   angry

# %% [markdown]
# CaFE

# %%
cafe_path = f'{DATA_PATH}/CaFE'
cafe_df = pd.DataFrame(columns=COLUMNS)
cafe_language = 'frCA'
cafe_language_family = 'Indo-European'

emotion_map_cafe = {'C' : 'angry', 
                    'D' : 'disgusted', 
                    'J' : 'happy',
                    'N' : 'neutral', 
                    'P' : 'fearful',
                    'S' : 'surprised',
                    'T' : 'sad'}

# %%
for e in os.listdir(cafe_path):
    for intensity in os.listdir(f'{cafe_path}/{e}'):
        for audio_filename in os.listdir(f'{cafe_path}/{e}/{intensity}'):
            audio_path = f'{cafe_path}/{e}/{intensity}/{audio_filename}'
            audio_filename_splitted = audio_filename.split('-')

            if int(audio_filename_splitted[0]) % 2 == 0:
                gender = 'female'
            else:
                gender = 'male'

            emotion = emotion_map_cafe[audio_filename_splitted[1]]

            audio_file, sr = librosa.load(audio_path)
            audio_len = str(f'{len(audio_file) / sr}')

            df_row = pd.Series({'audio_path' : audio_path, 'audio_len' : audio_len, 'language' : cafe_language, 'language_family' : cafe_language_family, 'gender': gender, 'emotion' : emotion})
            cafe_df = cafe_df.append(df_row, ignore_index=True)

# %%
cafe_df.to_csv(f'{DF_PATH}/cafe_df.csv')
cafe_df.head()
# Out:
#                                           audio_path          audio_len  \
# 0  D:/licencjat/data/databases/CaFE/ColŐre/Faible...  0.755328798185941
# 1  D:/licencjat/data/databases/CaFE/angry/Faible/...  0.755328798185941
# 2  D:/licencjat/data/databases/CaFE/angry/Faible/...  0.755328798185941
# 3  D:/licencjat/data/databases/CaFE/angry/Faible/...  0.755328798185941
# 4  D:/licencjat/data/databases/CaFE/angry/Faible/...  0.755328798185941
#
#   language language_family gender emotion
# 0     frCA   Indo-European   male   angry
# 1     frCA   Indo-European   male   angry
# 2     frCA   Indo-European   male   angry
# 3     frCA   Indo-European   male   angry
# 4     frCA   Indo-European   male   angry

# %%
df = pd.DataFrame(columns=COLUMNS)

df = df.append(ravdness_df, ignore_index=True)
df = df.append(emodb_df, ignore_index=True)
df = df.append(savee_df, ignore_index=True)
df = df.append(tess_df, ignore_index=True)
df = df.append(emovo_df, ignore_index=True)
# Out:
# C:\Users\arekk\AppData\Local\Temp\ipykernel_24520\1020003067.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(ravdness_df, ignore_index=True)
# C:\Users\arekk\AppData\Local\Temp\ipykernel_24520\1020003067.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(emodb_df, ignore_index=True)
# C:\Users\arekk\AppData\Local\Temp\ipykernel_24520\1020003067.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(savee_df, ignore_index=True)
# C:\Users\arekk\AppData\Local\Temp\ipykernel_24520\1020003067.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(tess_df, ignore_index=True)
# C:\Users\arekk\AppData\Local\Temp\ipykernel_24520\1020003067.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(emovo_df, ignore_index=True)

# %%
df = df.sample(frac=1, ignore_index=True)

# %%
df.head(50)
# Out:
#                                            audio_path           audio_len  \
# 0   D:/licencjat/data/databases/TESS/OAF_disgust/O...  2.2741496598639457
# 1   D:/licencjat/data/databases/TESS/OAF_Pleasant_...  1.9848979591836735
# 2   D:/licencjat/data/databases/ravdness/Actor_11/...  3.5035374149659866
# 3   D:/licencjat/data/databases/TESS/YAF_fear/YAF_...   1.820907029478458
# 4   D:/licencjat/data/databases/TESS/OAF_Pleasant_...  1.9914285714285713
# 5   D:/licencjat/data/databases/TESS/YAF_happy/YAF...  1.8750113378684807
# 6   D:/licencjat/data/databases/TESS/YAF_neutral/Y...  2.0259410430839004
# 7   D:/licencjat/data/databases/ravdness/Actor_20/...  3.6369614512471657
# 8   D:/licencjat/data/databases/ravdness/Actor_05/...   4.304308390022676
# 9   D:/licencjat/data/databases/TESS/OAF_Fear/OAF_...  1.5410430839002267
# 10  D:/licencjat/data/databases/ravdness/Actor_05/...  3.9039002267573695
# 11  D:/licencjat/data/databases/TESS/YAF_disgust/Y...  2.6630385487528345
# 12  D:/licencjat/data/databases/TESS/YAF_disgust/Y...  2.5096598639455783
# 13  D:/licencjat/data/databases/emovo/m3/pau-m3-d1...  2.1333333333333333
# 14  D:/licencjat/data/databases/ravdness/Actor_07/...  3.5369160997732427
# 15  D:/licencjat/data/databases/ravdness/Actor_01/...  4.3710657596371885
# 16  D:/licencjat/data/databases/TESS/YAF_happy/YAF...  1.9836281179138322
# 17  D:/licencjat/data/databases/ravdness/Actor_16/...   4.237596371882086
# 18  D:/licencjat/data/databases/TESS/OAF_neutral/O...  1.9454421768707484
# 19  D:/licencjat/data/databases/TESS/OAF_angry/OAF...   1.576281179138322
# 20  D:/licencjat/data/databases/ravdness/Actor_18/...  3.4034467120181406
# 21  D:/licencjat/data/databases/TESS/YAF_pleasant_...  1.9275736961451246
# 22  D:/licencjat/data/databases/TESS/OAF_Sad/OAF_t...  2.4835827664399095
# 23  D:/licencjat/data/databases/Berlin_EMODB/wav/0...  3.1812698412698412
# 24  D:/licencjat/data/databases/TESS/YAF_happy/YAF...  1.9759183673469387
# 25  D:/licencjat/data/databases/TESS/YAF_disgust/Y...    2.52108843537415
# 26  D:/licencjat/data/databases/TESS/OAF_angry/OAF...   1.539047619047619
# 27  D:/licencjat/data/databases/TESS/OAF_angry/OAF...  1.7024036281179138
# 28   D:/licencjat/data/databases/savee/ALL/JE_a02.wav   3.093922902494331
# 29  D:/licencjat/data/databases/Berlin_EMODB/wav/1...   2.655918367346939
# 30  D:/licencjat/data/databases/Berlin_EMODB/wav/1...  2.9947845804988664
# 31  D:/licencjat/data/databases/emovo/f2/tri-f2-n4...   4.565351473922902
# 32  D:/licencjat/data/databases/emovo/f2/neu-f2-b2...  2.1973696145124717
# 33  D:/licencjat/data/databases/TESS/OAF_happy/OAF...  1.9678004535147393
# 34  D:/licencjat/data/databases/TESS/OAF_angry/OAF...  1.3779591836734695
# 35  D:/licencjat/data/databases/TESS/OAF_Pleasant_...   2.098095238095238
# 36  D:/licencjat/data/databases/Berlin_EMODB/wav/1...  2.6313832199546487
# 37  D:/licencjat/data/databases/TESS/OAF_angry/OAF...   1.482312925170068
# 38   D:/licencjat/data/databases/savee/ALL/JE_d08.wav   4.288662131519274
# 39  D:/licencjat/data/databases/TESS/OAF_disgust/O...   2.371655328798186
# 40  D:/licencjat/data/databases/ravdness/Actor_09/...  3.5369160997732427
# 41   D:/licencjat/data/databases/savee/ALL/DC_n20.wav  3.2914285714285714
# 42  D:/licencjat/data/databases/emovo/m2/tri-m2-b3...  2.1120181405895693
# 43  D:/licencjat/data/databases/TESS/OAF_angry/OAF...  1.5068480725623583
# 44  D:/licencjat/data/databases/TESS/OAF_Sad/OAF_n...   2.374240362811791
# 45  D:/licencjat/data/databases/ravdness/Actor_15/...   3.737097505668934
# 46  D:/licencjat/data/databases/TESS/OAF_Fear/OAF_...  1.7718367346938775
# 47  D:/licencjat/data/databases/TESS/OAF_disgust/O...  2.3476643990929706
# 48  D:/licencjat/data/databases/ravdness/Actor_03/...   4.037414965986395
# 49  D:/licencjat/data/databases/savee/ALL/DC_sa04.wav   5.983673469387755
#
#    language language_family  gender    emotion
# 0      enCA   Indo-European    male  disgusted
# 1      enCA   Indo-European    male  surprised
# 2      enUS   Indo-European    male      happy
# 3      enCA   Indo-European    male    fearful
# 4      enCA   Indo-European    male  surprised
# 5      enCA   Indo-European    male      happy
# 6      enCA   Indo-European    male    neutral
# 7      enUS   Indo-European  female    neutral
# 8      enUS   Indo-European    male    neutral
# 9      enCA   Indo-European    male    fearful
# 10     enUS   Indo-European    male  disgusted
# 11     enCA   Indo-European    male  disgusted
# 12     enCA   Indo-European    male  disgusted
# 13     itIT   Indo-European    male    fearful
# 14     enUS   Indo-European    male        sad
# 15     enUS   Indo-European    male  disgusted
# 16     enCA   Indo-European    male      happy
# 17     enUS   Indo-European  female  disgusted
# 18     enCA   Indo-European    male    neutral
# 19     enCA   Indo-European    male      angry
# 20     enUS   Indo-European  female    neutral
# 21     enCA   Indo-European    male  surprised
# 22     enCA   Indo-European    male        sad
# 23     deDE   Indo-European  female    fearful
# 24     enCA   Indo-European    male      happy
# 25     enCA   Indo-European    male  disgusted
# 26     enCA   Indo-European    male      angry
# 27     enCA   Indo-European    male      angry
# 28     enGB   Indo-European    male      angry
# 29     deDE   Indo-European    male      angry
# 30     deDE   Indo-European  female      bored
# 31     itIT   Indo-European  female        sad
# 32     itIT   Indo-European  female    neutral
# 33     enCA   Indo-European    male      happy
# 34     enCA   Indo-European    male      angry
# 35     enCA   Indo-European    male  surprised
# 36     deDE   Indo-European    male      angry
# 37     enCA   Indo-European    male      angry
# 38     enGB   Indo-European    male  disgusted
# 39     enCA   Indo-European    male  disgusted
# 40     enUS   Indo-European    male      angry
# 41     enGB   Indo-European    male    neutral
# 42     itIT   Indo-European    male        sad
# 43     enCA   Indo-European    male      angry
# 44     enCA   Indo-European    male        sad
# 45     enUS   Indo-European    male      angry
# 46     enCA   Indo-European    male    fearful
# 47     enCA   Indo-European    male  disgusted
# 48     enUS   Indo-European    male    neutral
# 49     enGB   Indo-European    male        sad

# %%
df.groupby('emotion').count()['audio_path']
# Out:
# emotion
# angry        1182
# bored         162
# disgusted    1020
# fearful      1066
# happy        1070
# neutral      1338
# sad          1052
# surprised     928
# Name: audio_path, dtype: int64

# %%
df = df.loc[df['emotion'].isin(['angry', 'fearful', 'happy', 'neutral', 'sad'])]
df.head(50)
# Out:
#                                            audio_path           audio_len  \
# 0   D:/licencjat/data/databases/TESS/OAF_Fear/OAF_...  1.4480725623582766
# 2   D:/licencjat/data/databases/ravdness/Actor_18/...   4.237596371882086
# 5   D:/licencjat/data/databases/ravdness/Actor_15/...   3.703718820861678
# 7   D:/licencjat/data/databases/TESS/OAF_neutral/O...  1.8376417233560092
# 8   D:/licencjat/data/databases/TESS/YAF_angry/YAF...   1.956281179138322
# 9   D:/licencjat/data/databases/TESS/OAF_happy/OAF...  1.7905668934240362
# 10  D:/licencjat/data/databases/TESS/OAF_angry/OAF...  1.3951927437641722
# 11  D:/licencjat/data/databases/ravdness/Actor_21/...   4.237596371882086
# 13  D:/licencjat/data/databases/ravdness/Actor_21/...    4.13750566893424
# 14  D:/licencjat/data/databases/Berlin_EMODB/wav/1...  1.7219501133786848
# 16  D:/licencjat/data/databases/Berlin_EMODB/wav/0...   2.442040816326531
# 17  D:/licencjat/data/databases/savee/ALL/DC_sa03.wav  2.4229478458049885
# 19  D:/licencjat/data/databases/ravdness/Actor_14/...  3.4034013605442177
# 20  D:/licencjat/data/databases/TESS/YAF_fear/YAF_...   2.003718820861678
# 21  D:/licencjat/data/databases/ravdness/Actor_08/...  3.4034467120181406
# 22   D:/licencjat/data/databases/savee/ALL/JE_n08.wav   3.176145124716553
# 23  D:/licencjat/data/databases/ravdness/Actor_05/...  3.1364625850340135
# 24  D:/licencjat/data/databases/TESS/YAF_neutral/Y...  2.2118820861678006
# 25  D:/licencjat/data/databases/Berlin_EMODB/wav/1...   2.549342403628118
# 26  D:/licencjat/data/databases/ravdness/Actor_11/...    3.47015873015873
# 27  D:/licencjat/data/databases/ravdness/Actor_24/...   3.737097505668934
# 28  D:/licencjat/data/databases/emovo/f1/tri-f1-n5...   4.864036281179138
# 30  D:/licencjat/data/databases/ravdness/Actor_24/...   4.104126984126984
# 31  D:/licencjat/data/databases/Berlin_EMODB/wav/1...    4.06485260770975
# 32  D:/licencjat/data/databases/ravdness/Actor_17/...   3.703718820861678
# 33  D:/licencjat/data/databases/ravdness/Actor_21/...   4.070748299319728
# 34  D:/licencjat/data/databases/ravdness/Actor_23/...  3.2365986394557824
# 36  D:/licencjat/data/databases/TESS/YAF_neutral/Y...  2.0946485260770977
# 37  D:/licencjat/data/databases/ravdness/Actor_02/...   3.737097505668934
# 38  D:/licencjat/data/databases/TESS/OAF_Fear/OAF_...  1.4231292517006802
# 39  D:/licencjat/data/databases/ravdness/Actor_12/...    3.47015873015873
# 41  D:/licencjat/data/databases/TESS/YAF_neutral/Y...  2.1728798185941045
# 42  D:/licencjat/data/databases/ravdness/Actor_09/...   3.436780045351474
# 43  D:/licencjat/data/databases/ravdness/Actor_10/...  3.5369160997732427
# 44  D:/licencjat/data/databases/Berlin_EMODB/wav/0...   3.165578231292517
# 46   D:/licencjat/data/databases/savee/ALL/KL_n07.wav   3.815374149659864
# 47  D:/licencjat/data/databases/ravdness/Actor_15/...  3.2699773242630386
# 49  D:/licencjat/data/databases/ravdness/Actor_02/...   4.004036281179138
# 50  D:/licencjat/data/databases/TESS/OAF_happy/OAF...   1.897641723356009
# 52  D:/licencjat/data/databases/Berlin_EMODB/wav/1...   2.790294784580499
# 53  D:/licencjat/data/databases/ravdness/Actor_22/...   3.703718820861678
# 54  D:/licencjat/data/databases/ravdness/Actor_07/...  3.9039455782312924
# 56  D:/licencjat/data/databases/ravdness/Actor_04/...    3.83718820861678
# 57  D:/licencjat/data/databases/emovo/f3/gio-f3-d2...  1.8773696145124716
# 58  D:/licencjat/data/databases/ravdness/Actor_05/...    4.13750566893424
# 59  D:/licencjat/data/databases/TESS/YAF_fear/YAF_...  1.8649433106575963
# 60  D:/licencjat/data/databases/TESS/OAF_happy/OAF...  2.0003628117913834
# 61   D:/licencjat/data/databases/savee/ALL/JE_n06.wav   3.975873015873016
# 62  D:/licencjat/data/databases/TESS/YAF_fear/YAF_...   1.740907029478458
# 63  D:/licencjat/data/databases/TESS/OAF_Fear/OAF_...  1.5710204081632653
#
#    language language_family  gender  emotion
# 0      enCA   Indo-European  female  fearful
# 2      enUS   Indo-European  female    angry
# 5      enUS   Indo-European    male    angry
# 7      enCA   Indo-European  female  neutral
# 8      enCA   Indo-European  female    angry
# 9      enCA   Indo-European  female    happy
# 10     enCA   Indo-European  female    angry
# 11     enUS   Indo-European    male    angry
# 13     enUS   Indo-European    male    angry
# 14     deDE   Indo-European    male  neutral
# 16     deDE   Indo-European    male    angry
# 17     enGB   Indo-European    male      sad
# 19     enUS   Indo-European  female  fearful
# 20     enCA   Indo-European  female  fearful
# 21     enUS   Indo-European  female  neutral
# 22     enGB   Indo-European    male  neutral
# 23     enUS   Indo-European    male  fearful
# 24     enCA   Indo-European  female  neutral
# 25     deDE   Indo-European    male    angry
# 26     enUS   Indo-European    male  fearful
# 27     enUS   Indo-European  female    happy
# 28     itIT   Indo-European  female      sad
# 30     enUS   Indo-European  female      sad
# 31     deDE   Indo-European    male    angry
# 32     enUS   Indo-European    male    angry
# 33     enUS   Indo-European    male  fearful
# 34     enUS   Indo-European    male    happy
# 36     enCA   Indo-European  female  neutral
# 37     enUS   Indo-European  female      sad
# 38     enCA   Indo-European  female  fearful
# 39     enUS   Indo-European  female  fearful
# 41     enCA   Indo-European  female  neutral
# 42     enUS   Indo-European    male  neutral
# 43     enUS   Indo-European  female      sad
# 44     deDE   Indo-European  female    angry
# 46     enGB   Indo-European    male  neutral
# 47     enUS   Indo-European    male  fearful
# 49     enUS   Indo-European  female  neutral
# 50     enCA   Indo-European  female    happy
# 52     deDE   Indo-European    male  neutral
# 53     enUS   Indo-European  female      sad
# 54     enUS   Indo-European    male  neutral
# 56     enUS   Indo-European  female    angry
# 57     itIT   Indo-European  female    happy
# 58     enUS   Indo-European    male    happy
# 59     enCA   Indo-European  female  fearful
# 60     enCA   Indo-European  female    happy
# 61     enGB   Indo-European    male  neutral
# 62     enCA   Indo-European  female  fearful
# 63     enCA   Indo-European  female  fearful

# %%
df.groupby('emotion').count()['audio_path']
# Out:
# emotion
# angry      1182
# fearful    1066
# happy      1070
# neutral    1338
# sad        1052
# Name: audio_path, dtype: int64

# %%
df.groupby('language').count()['audio_path']
# Out:
# language
# deDE     816
# enCA    2000
# enGB     360
# enUS    2112
# itIT     420
# Name: audio_path, dtype: int64

# %%
df.groupby('gender').count()['audio_path']
# Out:
# gender
# female    3708
# male      2000
# Name: audio_path, dtype: int64
